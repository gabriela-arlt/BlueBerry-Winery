# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# null hypothesis- one categorical
# from scipy import stats

# F, p = stats.f_oneway(red_wine[red_wine['quality_label'] == 'low']['alcohol'],
# red_wine[red_wine['quality_label'] == 'medium']['alcohol'],
# red_wine[red_wine['quality_label'] == 'high']['alcohol'])
# print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
# print('F Statistic:', F, '\tp-value:', p)

# %% [markdown]
# ## Heatmap RED WINE

# %%
red_wine_heatmap = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
white_wine_heatmap = pd.read_csv('winequality-white.csv', sep=';')

# %%
white_wine_heatmap
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_wine_heatmap.drop_duplicates(inplace=True)
red_wine_heatmap.drop_duplicates(inplace=True)
white_wine_heatmap.reset_index(inplace=True)
red_wine_heatmap.reset_index(inplace=True)
red_wine_heatmap.drop(columns='index', inplace=True)
white_wine_heatmap.drop(columns='index', inplace=True)

# %%
white_wine_heatmap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3961 non-null   float64
#  1   volatile acidity      3961 non-null   float64
#  2   citric acid           3961 non-null   float64
#  3   residual sugar        3961 non-null   float64
#  4   chlorides             3961 non-null   float64
#  5   free sulfur dioxide   3961 non-null   float64
#  6   total sulfur dioxide  3961 non-null   float64
#  7   density               3961 non-null   float64
#  8   pH                    3961 non-null   float64
#  9   sulphates             3961 non-null   float64
#  10  alcohol               3961 non-null   float64
#  11  quality               3961 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 371.5 KB

# %% [markdown]
# ## Lecture

# %%
red_wine_heatmap.hist(bins=4, color='red', edgecolor='black', linewidth=3.0, xlabelsize=6, ylabelsize=6, grid=False)

plt.tight_layout(rect=(0, 0,1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
white_wine_heatmap.hist(bins=4, color='#ffeda0', edgecolor='black', linewidth=3.0, xlabelsize=6, ylabelsize=6, grid=False)

plt.tight_layout(rect=(0, 0,1.2, 1.2))

rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %%
# add column wine type
red_wine_heatmap['wine type']='red'
white_wine_heatmap['wine type']='white'
wine=pd.concat([red_wine_heatmap, white_wine_heatmap], ignore_index=True)
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 5315            6.2              0.21         0.29             1.6      0.039
# 5316            6.6              0.32         0.36             8.0      0.047
# 5317            6.5              0.24         0.19             1.2      0.041
# 5318            5.5              0.29         0.30             1.1      0.022
# 5319            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
numeric_wine=wine.iloc[:, 0:12]
corr=numeric_wine.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.214752     0.330328
# volatile acidity           0.214752          1.000000    -0.384192
# citric acid                0.330328         -0.384192     1.000000
# residual sugar            -0.104439         -0.163696     0.146189
# chlorides                  0.288918          0.367626     0.055199
# free sulfur dioxide       -0.281590         -0.349039     0.130849
# total sulfur dioxide      -0.327471         -0.400716     0.194835
# density                    0.478180          0.308452     0.094758
# pH                        -0.271182          0.246687    -0.344735
# sulphates                  0.304844          0.227772     0.059183
# alcohol                   -0.102573         -0.065411    -0.005496
# quality                   -0.080092         -0.265205     0.097954
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# ## Add quality label

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
wine['quality label'] = wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
wine['quality label'] = pd.Categorical(wine['quality label'],
categories=['low', 'medium', 'high'])
wine.drop('quality_label',inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[460], line 9
#       6 # here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
#       7 wine['quality label'] = pd.Categorical(wine['quality label'],
#       8 categories=['low', 'medium', 'high'])
# ----> 9 wine.drop('quality_label',inplace=True, axis=1)
#
# File c:\Users\gabb_\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
# ...

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality wine type quality label
# ...

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
gabi=['mediumvioletred', 'moccasin']
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='residual sugar',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Residual Sugar', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does Residual Sugar affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='alcohol',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Alcohol %', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does % Alcohol affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")
ax.set_ylim(6)
# Out:
# (6.0, 12.766764705882354)

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='volatile acidity',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Volatile acidity g/dm3', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does Volatile acidity affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='total sulfur dioxide',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Total sulfur dioxide mg/dm3', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does total sulfur dioxide affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })# changes background to black
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='fixed acidity',data=wine, palette=gabi, hue='wine type', errorbar=None)
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Fixed acidity g/dm3 ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does fixed acidity affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='pH',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('pH ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does pH affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")
ax.set_ylim(3)
# Out:
# (3.0, 3.4769209401709404)

# %% [markdown]
# ## pH may be
# ## fREE SULFUR DIOXIDE NO
# ## density NO

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='density',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('density ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does density affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")
ax.set_ylim(0.8)
# Out:
# (0.8, 1.04689569140625)

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='sulphates',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Suphates g/dm3 ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does amount of sulphates affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='chlorides',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Chlorides g/dm3 ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does amount of chlorides affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='citric acid',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Citric acid g/dm3 ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does citric acid affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='sulphates',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Suphates g/dm3 ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does amount of sulphates affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
fig , ax = plt.subplots (figsize = (7,7))
sns.barplot(x='quality label',y='total sulfur dioxide',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Total sulfur dioxide mg/dm3 ', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does total sulfur dioxide affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine_heatmap['quality label'] = red_wine_heatmap['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine_heatmap['quality label'] = pd.Categorical(red_wine_heatmap['quality label'],
categories=['low', 'medium', 'high'])

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine_heatmap['quality label'] = white_wine_heatmap['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine_heatmap['quality label'] = pd.Categorical(white_wine_heatmap['quality label'],
categories=['low', 'medium', 'high'])

# %% [markdown]
# # hypothesis check

# %%
from scipy import stats

# %%
#ALCOHOL YES
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['alcohol'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['alcohol'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 187.64407258778138 	p-value: 1.1419488265314005e-72

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['alcohol'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['alcohol'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['alcohol'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', {f: .5}p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 444.12133010661915 	p-value: 9.722633357986553e-175

# %%
#pH
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['pH'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['pH'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['pH'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 0.4933049630979343 	p-value: 0.6107145654590622

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['pH'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['pH'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['pH'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 24.631394572025133 	p-value: 2.3374654585169868e-11

# %%
#free sulfur dioxide
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['free sulfur dioxide'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['free sulfur dioxide'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['free sulfur dioxide'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 3.4313519702326327 	p-value: 0.03262429133727355

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['free sulfur dioxide'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['free sulfur dioxide'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['free sulfur dioxide'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 0.11569157788750334 	p-value: 0.8907529199895233

# %%
#fixed acidity
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['fixed acidity'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['fixed acidity'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['fixed acidity'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 5.758465821295056 	p-value: 0.003233632419644424

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['fixed acidity'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['fixed acidity'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['fixed acidity'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 20.73558869089151 	p-value: 1.100270476542302e-09

# %%
#density
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['density'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['density'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['density'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 24.519858591738284 	p-value: 3.460972032763999e-11

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['density'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['density'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['density'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 205.93067592683016 	p-value: 8.300292842765813e-86

# %%
# total sulfur dioxide
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['total sulfur dioxide'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['total sulfur dioxide'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['total sulfur dioxide'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 39.861286637115725 	p-value: 1.507478282446513e-17

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['total sulfur dioxide'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['total sulfur dioxide'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['total sulfur dioxide'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 63.72731803883069 	p-value: 5.752429178024611e-28

# %%
# volatile acidity
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['volatile acidity'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['volatile acidity'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['volatile acidity'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 81.95632590559691 	p-value: 2.506330246976263e-34

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['volatile acidity'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['volatile acidity'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['volatile acidity'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 107.93958082775238 	p-value: 2.2708174890091537e-46

# %%
#sulphates
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['sulphates'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['sulphates'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['sulphates'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 33.9108543026188 	p-value: 4.2576090028540455e-15

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['sulphates'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['sulphates'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['sulphates'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 6.293007633619428 	p-value: 0.0018677453892720543

# %%
# chlorides
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['chlorides'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['chlorides'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['chlorides'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 9.859608363198346 	p-value: 5.608704400164339e-05

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['chlorides'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['chlorides'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['chlorides'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 81.89267741204402 	p-value: 1.414612016009444e-35

# %%
#citric acid
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['citric acid'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['citric acid'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['citric acid'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 21.198716389006055 	p-value: 8.600238562416517e-10

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['citric acid'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['citric acid'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['citric acid'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 0.24868681586895755 	p-value: 0.7798363477964527

# %%
# residual sugar
F, p = stats.f_oneway(red_wine_heatmap[red_wine_heatmap['quality label'] == 'low']['residual sugar'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'medium']['residual sugar'],
red_wine_heatmap[red_wine_heatmap['quality label'] == 'high']['residual sugar'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 0.018769916621439144 	p-value: 0.9814053962580443

# %%
F, p = stats.f_oneway(white_wine_heatmap[white_wine_heatmap['quality label'] == 'low']['residual sugar'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'medium']['residual sugar'],
white_wine_heatmap[white_wine_heatmap['quality label'] == 'high']['residual sugar'])
print('ANOVA test for mean alcohol levels across wine samples with different quality ratings')
print('F Statistic:', F, '\tp-value:', p)
# Out:
# ANOVA test for mean alcohol levels across wine samples with different quality ratings
# F Statistic: 24.845314141476056 	p-value: 1.8922918391165555e-11

# %%
fig1, ax1 = plt.subplots()
gabi1=['#99d8c9','#2ca25f','#a8ddb5']
labels='Red Wine','White Wine'
sns.countplot(data = wine , x = 'quality label', palette=gabi1)
plt.suptitle('Quality label count', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='black')
plt.xlabel(xlabel='quality label',color='black')
plt.ylabel(ylabel='count',color='black')
ax1.bar_label(ax1.containers[0], color='white')
sns.despine(left=True)

# %% [markdown]
# ## Red Wine

# %%
gabi2=['yellow','purple']
sns.scatterplot(x='alcohol', y='volatile acidity', hue='quality label',s=100, data=red_wine_heatmap, palette=gabi2)
plt.suptitle('Alcohol to volatile acidity', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='alcohol',color='white')
plt.ylabel(ylabel='volatile acidity',color='white')
plt.rcParams['text.color'] = 'white'
#fig1.patch.set_facecolor('black')
plt.legend(title="Quality labels", facecolor='black')
# Out:
# C:\Users\gabb_\AppData\Local\Temp\ipykernel_32748\4206609505.py:2: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x='alcohol', y='volatile acidity', hue='quality label',s=100, data=red_wine_heatmap, palette=gabi2)

# %%
gabi2=['purple','yellow']
sns.scatterplot(x='fixed acidity', y='pH',s=80,   hue='wine type', alpha=0.2, data=wine, palette=gabi2)
plt.suptitle('Fixed acidity to pH', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='fixed acidity',color='white')
plt.ylabel(ylabel='pH',color='white')
plt.rcParams['text.color'] = 'white'
#fig1.patch.set_facecolor('black')
plt.legend(title="Wine types", facecolor='black')

# %% [markdown]
# gabi2=['yellow','orange','red']
# sns.scatterplot(x='alcohol', y='density', hue='quality label',s=100, data=red_wine_heatmap, palette=gabi2)
# plt.suptitle('density to alcohol', color='white')
# plt.xticks(fontsize=15, color='white')
# plt.yticks(fontsize=10, color='white')
# plt.xlabel(xlabel='alcohol',color='white')
# plt.ylabel(ylabel='density',color='white')
# plt.rcParams['text.color'] = 'white'
# #fig1.patch.set_facecolor('black')
# plt.legend(title="Quality labels", facecolor='black')

# %% [markdown]
# ## WHITE wine

# %%
gabi2=['yellow','orange','red']
sns.scatterplot(x='residual sugar', y='density', hue='quality label',s=100, data=white_wine_heatmap, palette=gabi2)
plt.suptitle('density to fixed acidity', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='alcohol',color='white')
plt.ylabel(ylabel='residual sugar',color='white')
plt.rcParams['text.color'] = 'white'
#fig1.patch.set_facecolor('black')
plt.legend(title="Quality labels", facecolor='black')

# %%
gabi2=['yellow','orange','red']
sns.scatterplot(x='alcohol', y='density', hue='quality label',s=100, data=white_wine_heatmap, palette=gabi2)
plt.suptitle('density to fixed acidity', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='alcohol',color='white')
plt.ylabel(ylabel='density',color='white')
plt.rcParams['text.color'] = 'white'
#fig1.patch.set_facecolor('black')
plt.legend(title="Quality labels", facecolor='black')

# %% [markdown]
# ## RED WINE

# %% [markdown]
# # plt.figure(figsize=(5, 5))
# sns.lineplot(x='quality label', y='citric acid', data=red_wine_heatmap, marker='o', label='Citric acid')
# sns.lineplot(x='quality label', y='sulphates', data=red_wine_heatmap, marker='o', label='Sulphates')
# plt.suptitle('Correlation between citric acid, sulphates and quality', color='white')
# plt.xticks(fontsize=15, color='white')
# plt.yticks(fontsize=10, color='white')
# plt.xlabel(xlabel='quality',color='white')
# plt.ylabel(ylabel='citric acid  sulphates', color='white')
# plt.legend()
# plt.show()

# %%
numerical12_data = red_wine_heatmap.groupby('quality label')['alcohol'].mean()

# Plotting with Matplotlib
plt.figure(figsize=(5, 5))
plt.plot(numerical12_data.index, numerical12_data, marker='o', color='#99d8c9', linewidth=15, label='Alcohol')


plt.suptitle('Correlation between Quality label and Alcohol', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Qaulity label',color='white')
plt.ylabel(ylabel='Alcohol', color='white')

#plt.legend()
plt.show()

# %%
numerical11_data = wine.groupby('quality label')['residual sugar'].mean()

# Plotting with Matplotlib
plt.figure(figsize=(5, 5))
plt.plot(numerical11_data.index, numerical11_data, marker='o', color='#fff7bc', linewidth=15, label='Residual Sugar')


plt.suptitle('Correlation between Quality label and Residual Sugar', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Qaulity label',color='white')
plt.ylabel(ylabel='Residual Sugar', color='white')

#plt.legend()
plt.show()

# %%
numerical1_data = wine.groupby('quality label')['fixed acidity'].mean()
numerical2_data = wine.groupby('quality label')['pH'].mean()

# Plotting with Matplotlib
plt.figure(figsize=(5, 5))
plt.plot(numerical1_data.index, numerical1_data, marker='o', color='#31a354', linewidth=15, label='Citric Acid Red')
plt.plot(numerical2_data.index, numerical2_data, marker='o', color='#addd8e', linewidth=15, label='Citric Acid White')

plt.suptitle('Correlation between Citric Acid and Quality', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Quality label',color='white')
plt.ylabel(ylabel='legend', color='black')
plt.legend()
plt.show()

# %%
numerical3_data = red_wine_heatmap.groupby('quality label')['volatile acidity'].mean()

# Plotting with Matplotlib
plt.figure(figsize=(5, 5))
plt.plot(numerical3_data.index, numerical3_data, marker='o', color='#c51b8a', linewidth=15, label='Volatile Acidity')


plt.suptitle('Correlation between Quality label and Average Volatile Acidity', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Qaulity label',color='white')
plt.ylabel(ylabel='Volatile Acidity', color='white')

#plt.legend()
plt.show()

# %% [markdown]
# ## White Wine

# %%
# DENSITY
numerical4_data = white_wine_heatmap.groupby('quality label')['density'].mean()

# Plotting with Matplotlib
plt.figure(figsize=(5, 5))
plt.plot(numerical4_data.index, numerical4_data, marker='o', color='#c51b8a', linewidth=15, label='Density')


plt.suptitle('Correlation between Quality label and Average Density', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Qaulity label',color='white')
plt.ylabel(ylabel='Density', color='white')

#plt.legend()
plt.show()

# %%
# AlCOHOL
numerical4_data = white_wine_heatmap.groupby('quality label')['alcohol'].mean()

# Plotting with Matplotlib
plt.figure(figsize=(5, 5))
plt.plot(numerical4_data.index, numerical4_data, marker='o', color='#addd8e', linewidth=15, label='Density')


plt.suptitle('Correlation between Quality label and Average Density', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Qaulity label',color='white')
plt.ylabel(ylabel='Density', color='white')

#plt.legend()
plt.show()

# %%
# AlCOHOL
numerical15_data = white_wine_heatmap.groupby('quality label')['fixed acidity'].mean()

# Plotting with Matplotlib
plt.figure(figsize=(5, 5))
plt.plot(numerical15_data.index, numerical15_data, marker='o', color='#c51b8a', linewidth=15, label='Residual Sugar')


plt.suptitle('Correlation between Quality label and Residual Sugar', color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Qaulity label',color='white')
plt.ylabel(ylabel='Residual Sugar', color='white')

#plt.legend()
plt.show()

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine_heatmap['quality label'] = red_wine_heatmap['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine_heatmap['quality label'] = pd.Categorical(red_wine_heatmap['quality label'],
categories=['low', 'medium', 'high'])

# %%
### RED WINE   POSITIVE 
## ALCOHOL
# 1.alcohol shows positive correlation to ph and citric acid
# 2. alcohol has negative corr to density and volatile acidity

## SULPHATES
# 1. sulphates show positive corr with chlorides and citric acid
# 2. sul shows NEG corr to volatile acidity and  ph

### RED WINE   NEGATIVE
# 1. volatile acidity and (total sulfur dioxide and density) 
# 2. volatile acidity is positively corr to pH
# 3. density is pos corr to fixed acidity, citric acid, residual sugar

# %%
### WHITE WINE   POSITIVE 
# alcohol and ph
# 1.alcohol POS to pH and NEG to density
# 2.ph is POS to sulphates and NEG to fixed acidity


# white wine negative
#  density and chlorides
# 2. density is POS to residual sugar and NEG to pH (quality and alcohol)
# 3. chlorides = totla sulfur dioxide and density, and NEG to quality alcohol and pH

# %% [markdown]
# ## heatmap

# %%
numeric_white_wine=white_wine_heatmap.iloc[:, 0:13]
corr_white=numeric_wine.corr()
corr_white
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.214752     0.330328
# volatile acidity           0.214752          1.000000    -0.384192
# citric acid                0.330328         -0.384192     1.000000
# residual sugar            -0.104439         -0.163696     0.146189
# chlorides                  0.288918          0.367626     0.055199
# free sulfur dioxide       -0.281590         -0.349039     0.130849
# total sulfur dioxide      -0.327471         -0.400716     0.194835
# density                    0.478180          0.308452     0.094758
# pH                        -0.271182          0.246687    -0.344735
# sulphates                  0.304844          0.227772     0.059183
# alcohol                   -0.102573         -0.065411    -0.005496
# quality                   -0.080092         -0.265205     0.097954
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import numpy as np

# %%
matrix=np.triu(corr_white)
matrix
fig , ax = plt.subplots (figsize = (10,10))
sns.heatmap(data=corr_white, mask=matrix, square=True, cmap='Spectral', vmin=-1, vmax=1, annot=True,cbar=False, linewidths=0.5)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.title('White Wine Correlation', fontsize=15, color='white')
# Out:
# Text(0.5, 1.0, 'White Wine Correlation')

# %%
numeric_red_wine=red_wine_heatmap.iloc[:,0:12]
corr_red=numeric_red_wine.corr()
corr_red
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
matrix=np.triu(corr_red)
matrix
sns.color_palette("dark:salmon_r", as_cmap=True)
fig , ax = plt.subplots (figsize = (10,10))
sns.heatmap(data=corr_red, mask=matrix, square=True, vmin=-1, vmax=1, annot=True, cbar=False, linewidths=0.5)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.title('Red Wine Correlation',fontsize=15, color='white')
# Out:
# Text(0.5, 1.0, 'Red Wine Correlation')

# %%
# Load the diamonds dataset
gabi5=['mediumvioletred', '#fee8c8']
# Plot the distribution of clarity ratings, conditional on carat
sns.displot(data=wine, x="residual sugar", hue="wine type", kind="kde", height=5, multiple="fill", clip=(0, None),palette=gabi5)
plt.suptitle('Density of Residual Sugar in the full dataset', x=0.45, y=1.05, color='white')
plt.xticks(fontsize=15, color='white')
plt.yticks(fontsize=10, color='white')
plt.xlabel(xlabel='Residual Sugar',color='white')
plt.ylabel(ylabel='Density',color='white')
plt.rcParams['text.color'] = 'white'
# Out:
# c:\Users\gabb_\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality wine type quality label
# 0      9.4        5       red           low

# %%
gabi_red=['#fde0dd', '#fa9fb5', '#c51b8a']
gabi_white=['papayawhip', 'navajowhite', 'orange']

fig, axs= plt.subplots(nrows = 1, ncols= 2, sharey = True, figsize = (7,5))
sns.boxplot(x = "quality label" , y = "pH", data = red_wine_heatmap, whiskerprops={'color': 'white'}, boxprops={'edgecolor': 'white'}, palette=gabi_red, ax=axs[1])
sns.boxplot(x = "quality label" , y = "pH", data = white_wine_heatmap, whiskerprops={'color': 'white'}, boxprops={'edgecolor': 'white'}, palette=gabi_white, ax=axs[0])
plt.suptitle('Fixed acidity to Quality', x=0.48, y=0.99, color='white')
axs[0].set_xlabel('Quality label', fontdict={'size': 12, 'weight': 'bold', 'color': 'white'})
axs[0].set_ylabel('Fixed acidity', fontdict={'size': 12, 'weight': 'bold', 'color': 'white'})
axs[1].set_xlabel('Quality label', fontdict={'size': 12, 'weight': 'bold', 'color': '#dd1c77'})
axs[1].set_ylabel('Fixed acidity', fontdict={'size': 12, 'weight': 'bold', 'color': '#dd1c77'})
axs[0].tick_params(axis='x', colors='white')
axs[0].tick_params(axis='y', colors='white')
axs[1].tick_params(axis='x', colors='white')
axs[1].tick_params(axis='y', colors='white')
#axs[1].set_title('White Wine', fontdict={'size': 15, 'weight': 'bold', 'color': 'white'})
#axs[0].set_title('Red Wine', fontdict={'size': 15, 'weight': 'bold', 'color': '#dd1c77'})
