# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
red_wine.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
white_wine.drop_duplicates()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# ## Isna()

# %%
red_wine.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
white_wine.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
# ...

# %% [markdown]
# ## Isnull()

# %%
red_wine.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
white_wine.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
# ...

# %% [markdown]
# ## Describe()

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ## Add column with low, medium, high

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %% [markdown]
# ## Check the new columns in both datasets

# %%
red_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label
# 0      9.4        5           low

# %%
white_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol  quality quality_label
# 0      8.8        6        medium

# %% [markdown]
# ## Add a new column with wine type

# %%
# we are creating a new column called "wine_type"
red_wine['wine_type'] = 'red'

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['wine_type'] = pd.Categorical(red_wine['wine_type'], categories=['red'])

# %%
# we are creating a new column called "wine_type"
white_wine['wine_type'] = 'white'

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['wine_type'] = pd.Categorical(white_wine['wine_type'], categories=['white'])

# %% [markdown]
# ## Check both datasets

# %%
red_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label wine_type
# 0      9.4        5           low       red

# %%
white_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol  quality quality_label wine_type
# 0      8.8        6        medium     white

# %% [markdown]
# ## Standardizing name columns

# %%
white_wine = white_wine.rename(columns=lambda x: x.replace(' ', '_'))
white_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine = red_wine.rename(columns=lambda x: x.replace(' ', '_'))
red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## Concat Describe for finding trends

# %% [markdown]
# Fixed acidity: acids are major wine properties and contribute greatly to the wine’s taste. Usually, the total acidity is divided into two groups: the volatile acids and the nonvolatile or fixed acids. Among the fixed acids that you can find in wines are the following: tartaric, malic, citric, and succinic. This variable is expressed in g(tartaricacid)/dm3 in the data sets.
#
# Volatile acidity: the volatile acidity is basically the process of wine turning into vinegar. In the U.S, the legal limits of Volatile Acidity are 1.2 g/L for red table wine and 1.1 g/L for white table wine. In these data sets, the volatile acidity is expressed in g(aceticacid)/dm3.
#
# Citric acid is one of the fixed acids that you’ll find in wines. It’s expressed in g/dm3 in the two data sets. Residual sugar typically refers to the sugar remaining after fermentation stops, or is stopped. It’s expressed in g/dm3 in the red and white data.
#
# Chlorides can be a significant contributor to saltiness in wine. Here, you’ll see that it’s expressed in g(sodiumchloride)/dm3.
#
# Free sulfur dioxide: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. This variable is expressed in mg/dm3 in the data.
#
# Total sulfur dioxide is the sum of the bound and the free sulfur dioxide (SO2). Here, it’s expressed in mg/dm3. There are legal limits for sulfur levels in wines: in the EU, red wines can only have 160mg/L, while white and rose wines can have about 210mg/L. Sweet wines are allowed to have 400mg/L. For the US, the legal limits are set at 350mg/L, and for Australia, this is 250mg/L.
#
# Density is generally used as a measure of the conversion of sugar to alcohol. Here, it’s expressed in g/cm3.
#
# pH or the potential of hydrogen is a numeric scale to specify the acidity or basicity the wine. As you might know, solutions with a pH less than 7 are acidic, while solutions with a pH greater than 7 are basic. With a pH of 7, pure water is neutral. Most wines have a pH between 2.9 and 3.9 and are therefore acidic.
#
# Sulfates are to wine as gluten is to food. You might already know sulfites from the headaches that they can cause. They are a regular part of wine making around the world and are considered necessary. In this case, they are expressed in g(potassiumsulphate)/dm3.
#
# Alcohol: wine is an alcoholic beverage, and as you know, the percentage of alcohol can vary from wine to wine. It shouldn’t be surprised that this variable is included in the data sets, where it’s expressed in % vol.
#
# Quality: wine experts graded the wine quality between 0 (very bad) and 10 (very excellent). The eventual number is the mean of at least three evaluations made by those same wine experts. Some analysts might combine these levels to Low, Medium & High-Quality wines.

# %%
#sulfates and volatile acidity are already clear

# %% [markdown]
# You can observe that the mean value of sulfates and volatile acidity seem to be higher in red wine as compared to white wine.
#
# Come up with few more observation and write them down in the form of #comment in your VSCode. This will help you undestand which features is worth investigating further, keeping in mind that we are trying first to understand the difference between red and white wines, and then their respective relations with the quality label.

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed_acidity volatile_acidity  citric_acid residual_sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
pd.concat([red_wine[['residual_sugar', 'total_sulfur_dioxide','sulphates', 'alcohol','volatile_acidity','quality']].describe(), white_wine[['residual_sugar', 'total_sulfur_dioxide','sulphates', 'alcohol','volatile_acidity','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                                 \
#        residual_sugar total_sulfur_dioxide    sulphates      alcohol
# count     1599.000000          1599.000000  1599.000000  1599.000000
# mean         2.538806            46.467792     0.658149    10.422983
# std          1.409928            32.895324     0.169507     1.065668
# min          0.900000             6.000000     0.330000     8.400000
# 25%          1.900000            22.000000     0.550000     9.500000
# 50%          2.200000            38.000000     0.620000    10.200000
# 75%          2.600000            62.000000     0.730000    11.100000
# max         15.500000           289.000000     2.000000    14.900000
#
#                                     White Wines Stats                       \
#       volatile_acidity      quality    residual_sugar total_sulfur_dioxide
# count      1599.000000  1599.000000       4898.000000          4898.000000
# ...

# %% [markdown]
# ### Fixed aciditiy is HIGHER in red wine

# %%
# AVG of fixed acidiy for red wine is higher than for the white wine/ std big difference

# Fixed acidity: acids are major wine properties and contribute greatly to the wine’s taste. Usually, the total acidity is divided into 
# two groups: the volatile acids and the nonvolatile or fixed acids. Among the fixed acids that you can find in wines are the following:
# tartaric, malic, citric, and succinic. This variable is expressed in g(tartaricacid)/dm3 in the data sets.

pd.concat([red_wine[['fixed_acidity','volatile_acidity']].describe(), white_wine[['fixed_acidity','volatile_acidity' ]].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                  White Wines Stats
#         fixed_acidity volatile_acidity     fixed_acidity volatile_acidity
# count     1599.000000      1599.000000       4898.000000      4898.000000
# mean         8.319637         0.527821          6.854788         0.278241
# std          1.741096         0.179060          0.843868         0.100795
# min          4.600000         0.120000          3.800000         0.080000
# 25%          7.100000         0.390000          6.300000         0.210000
# 50%          7.900000         0.520000          6.800000         0.260000
# 75%          9.200000         0.640000          7.300000         0.320000
# max         15.900000         1.580000         14.200000         1.100000

# %%
sns.boxplot(x = "quality_label" , y = "fixed_acidity", data = red_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='fixed_acidity'>

# %% [markdown]
# ### Free sulfur dioxide is LOWER in red wine

# %%
# AVG free sulfur dioxide for white wine is two times higher than the red whine/std also higher for white wine
# Free sulfur dioxide: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, 
# while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. 
# This variable is expressed in mg/dm3 in the data.

pd.concat([red_wine[['free_sulfur_dioxide']].describe(), white_wine[['free_sulfur_dioxide']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#           Red Wines Stats   White Wines Stats
#       free_sulfur_dioxide free_sulfur_dioxide
# count         1599.000000         4898.000000
# mean            15.874922           35.308085
# std             10.460157           17.007137
# min              1.000000            2.000000
# 25%              7.000000           23.000000
# 50%             14.000000           34.000000
# 75%             21.000000           46.000000
# max             72.000000          289.000000

# %%
sns.boxplot(x = "quality_label" , y = "free_sulfur_dioxide", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='free_sulfur_dioxide'>

# %% [markdown]
# ### Chloride is HIGHER in red wine

# %%
# avg cloride is higher for the red wine compared to the white wine also std
# Chlorides can be a significant contributor to saltiness in wine. Here, you’ll see that it’s expressed in g(sodiumchloride)/dm3

pd.concat([red_wine[['chlorides']].describe(), white_wine[['chlorides']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats White Wines Stats
#             chlorides         chlorides
# count     1599.000000       4898.000000
# mean         0.087467          0.045772
# std          0.047065          0.021848
# min          0.012000          0.009000
# 25%          0.070000          0.036000
# 50%          0.079000          0.043000
# 75%          0.090000          0.050000
# max          0.611000          0.346000

# %%
sns.boxplot(x = "quality_label" , y = "chlorides", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='chlorides'>

# %% [markdown]
# ### Residual sugar is 3 times LOWER  in red wine

# %%
# avg residual sugar us 3 times higher for white wine also std
pd.concat([red_wine[['residual_sugar']].describe(), white_wine[['residual_sugar']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats White Wines Stats
#        residual_sugar    residual_sugar
# count     1599.000000       4898.000000
# mean         2.538806          6.391415
# std          1.409928          5.072058
# min          0.900000          0.600000
# 25%          1.900000          1.700000
# 50%          2.200000          5.200000
# 75%          2.600000          9.900000
# max         15.500000         65.800000

# %%
sns.boxplot(x = "quality_label" , y = "residual_sugar", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='residual_sugar'>

# %% [markdown]
# ### Pie Chart REd and White

# %%
white_wine_count=white_wine['quality'].count()
red_wine_count=red_wine['quality'].count()

# %%
sizes=[red_wine_count, white_wine_count]
labels='Red Wine','White Wine'
explode=(0,0.5)
mycolors=['#dd1c77','#fff7bc']
plt.rcParams['text.color'] = 'white'

fig1, ax1 = plt.subplots()
#sns.set_style(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
ax1.pie(sizes, explode=explode, pctdistance=0.5, startangle=45,colors=mycolors)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig1.patch.set_facecolor('black')
plt.legend(title="Wine Types", labels=labels, facecolor='black')
# ax1.set_title('White wine + Red wine',loc='left')
# ax1.get_legend().set_title("Wine types", color='white')
#ax1.legend(labels, title="Wine types", loc="center left", bbox_to_anchor=(0, 0.5, 0.3, 1))
plt.show()

# %%
pd.concat([red_wine[['quality','alcohol']].describe(), white_wine[['quality','alcohol']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats              White Wines Stats
#               quality      alcohol           quality      alcohol
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         5.636023    10.422983          5.877909    10.514267
# std          0.807569     1.065668          0.885639     1.230621
# min          3.000000     8.400000          3.000000     8.000000
# 25%          5.000000     9.500000          5.000000     9.500000
# 50%          6.000000    10.200000          6.000000    10.400000
# 75%          6.000000    11.100000          6.000000    11.400000
# max          8.000000    14.900000          9.000000    14.200000

# %%
white_color_gabi=['#ffeda0','#fff7bc', '#feb24c']
red_color_gabi = ['#fde0dd', '#fa9fb5', '#c51b8a'] 
# sns.palplot(sns.color_palette())
sns.set_palette(white_color_gabi) 
sns.set_palette(red_color_gabi) 
# sns.palplot(sns.color_palette())
# ax.set_facecolor("violet")

# %%
fig, axs= plt.subplots(nrows = 1, ncols= 2, sharey = True, figsize = (7,5))
sns.boxplot(x = "quality_label" , y = "", data = red_wine, palette=red_color_gabi, ax=axs[1])
sns.boxplot(x = "quality_label" , y = "alcohol", data = white_wine, palette=white_color_gabi, ax=axs[0])

axs[0].set_title('White Wine')
axs[1].set_title('Red Wine')
axs[0].set_facecolor("#636363")
axs[1].set_facecolor("#636363")
axs[1].set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
sns.boxplot(x = "quality_label" , y = "alcohol", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='alcohol'>

# %%
sns.boxplot(x = "quality_label" , y = "residual_sugar", data = red_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='residual_sugar'>

# %%
sns.boxplot(x = "quality_label" , y = "density", data = red_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='density'>

# %%
sns.boxplot(x = "quality_label" , y = "density", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='density'>

# %%
sns.scatterplot(x = "residual_sugar" , y = "quality", data = red_wine , hue= "quality_label")
# Out:
# <Axes: xlabel='residual_sugar', ylabel='quality'>

# %% [markdown]
# ## Heatmap RED WINE

# %%
red_wine_heatmap = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
white_wine_heatmap = pd.read_csv('winequality-white.csv', sep=';')

# %%
white_wine_heatmap.drop_duplicates(inplace=True)
red_wine_heatmap.drop_duplicates(inplace=True)
white_wine_heatmap.reset_index(inplace=True)
red_wine_heatmap.reset_index(inplace=True)

# %%
red_wine_heatmap.head()
# Out:
#    index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      0            7.4              0.70         0.00             1.9
# 1      1            7.8              0.88         0.00             2.6
# 2      2            7.8              0.76         0.04             2.3
# 3      3           11.2              0.28         0.56             1.9
# 4      5            7.4              0.66         0.00             1.8
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.075                 13.0                  40.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# ...

# %%
corr_red=red_wine_heatmap.iloc[:, 1:13].corr()
corr_red
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.255124     0.667437
# volatile acidity          -0.255124          1.000000    -0.551248
# citric acid                0.667437         -0.551248     1.000000
# residual sugar             0.111025         -0.002449     0.143892
# chlorides                  0.085886          0.055154     0.210195
# free sulfur dioxide       -0.140580         -0.020945    -0.048004
# total sulfur dioxide      -0.103777          0.071701     0.047358
# density                    0.670195          0.023943     0.357962
# pH                        -0.686685          0.247111    -0.550310
# sulphates                  0.190269         -0.256948     0.326062
# alcohol                   -0.061596         -0.197812     0.105108
# quality                    0.119024         -0.395214     0.228057
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
fig , ax = plt.subplots (figsize = (10,7))
sns.heatmap(data=corr_red, cmap='Reds', vmin=-1, vmax=1, annot=True, cbar=False).set(title='RED wine Correlations')
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.title('Red Wine Correlation', color='white')
# Out:
# Text(0.5, 1.0, 'Red Wine Correlation')

# %%
#+++alcohol, sulphates,citric acid, fixed acid, residual sugar
#---pH,density, total_sulfur_dioxide, free_sulfur_dioxide,chlorides, volatile acidity

# %%
positive_red=red_wine_heatmap[['quality','alcohol', 'sulphates', 'citric acid','fixed acidity', 'residual sugar']]
negative_red=red_wine_heatmap[['quality', 'free sulfur dioxide','pH','chlorides','density','total sulfur dioxide','volatile acidity']]

# %%
corr_positive=positive_red.corr()
corr_negative=negative_red.corr()

# %%
sns.clustermap(corr_positive, annot=True)

# %%
fig1 , ax1 = plt.subplots (figsize = (10,7))
sns.heatmap(data=corr_positive, cmap='Reds', vmin=-1, vmax=1, annot=True).set(title='RED wine POS')
# Out:
# [Text(0.5, 1.0, 'RED wine POS')]

# %%
fig1 , ax1 = plt.subplots (figsize = (10,7))
sns.heatmap(data=corr_negative, cmap='Blues', vmin=-1, vmax=1, annot=True).set(title='Red wine NEG')
# Out:
# [Text(0.5, 1.0, 'Red wine NEG')]

# %% [markdown]
# ## Heatmap WHITE WINE

# %%
corr_white=white_wine_heatmap.iloc[:, 1:13].corr()
corr_white
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.019214     0.298959
# volatile acidity          -0.019214          1.000000    -0.163228
# citric acid                0.298959         -0.163228     1.000000
# residual sugar             0.083620          0.098340     0.106269
# chlorides                  0.024036          0.086287     0.132590
# free sulfur dioxide       -0.058396         -0.102471     0.091681
# total sulfur dioxide       0.082425          0.102315     0.122845
# density                    0.266091          0.060603     0.160076
# pH                        -0.431274         -0.046954    -0.183015
# sulphates                 -0.017453         -0.021150     0.049442
# alcohol                   -0.110788          0.046815    -0.076514
# quality                   -0.124636         -0.190678     0.007065
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
import numpy as np

# %%
matrix=np.triu(corr_white)
matrix
fig , ax = plt.subplots (figsize = (15,15))
sns.heatmap(data=corr_white, mask=matrix, square=True, cmap='Oranges', vmin=-1, vmax=1, annot=True, linewidths=0.5)
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.title('White Wine Correlation', color='white')
# Out:
# Text(0.5, 1.0, 'White Wine Correlation')

# %%
### positive - alcohol, pH, sulphates, free sulfur dioxide, citric acid
### negative - fixed acidity, residual sugar, total sulfur dioxide, volatile acidity, chlorides, density

# %%
positive_white=white_wine_heatmap[['quality','alcohol', 'pH', 'sulphates', 'free sulfur dioxide', 'citric acid']]
negative_white=white_wine_heatmap[['quality', 'fixed acidity', 'residual sugar', 'total sulfur dioxide', 'volatile acidity', 'chlorides', 'density']]

# %%
pos_white_corr=positive_white.corr()
neg_white_corr=negative_white.corr()

# %%
fig, axs= plt.subplots(nrows = 1, ncols= 2, figsize = (20,20))
fig.suptitle('Negative and Positive Corr in White Wine', color='red', fontsize=24)
matrix1=np.triu(pos_white_corr)
matrix2=np.triu(neg_white_corr)
plt.figure(figsize=(5,5))
sns.heatmap(data=pos_white_corr, mask=matrix1, square=True, cmap='vlag', vmin=-1, vmax=1, linewidths=0.5, ax=axs[0])
sns.heatmap(data=neg_white_corr, mask=matrix2, square=True, cmap='vlag', vmin=-1, vmax=1, linewidths=0.5, ax=axs[1])
# Out:
# <Axes: >

# %%
matrix2=np.triu(neg_white_corr)
plt.figure(figsize=(7,7))
sns.heatmap(data=neg_white_corr, mask=matrix2, square=True, cmap='vlag', vmin=-1, vmax=1,annot=True, linewidths=0.5).set(title='White Wine')
# Out:
# [Text(0.5, 1.0, 'White Wine')]

# %%
sns.heatmap(data=pos_white_corr, mask=matrix1, square=True, cmap='vlag', vmin=-1, vmax=1, linewidths=0.5).set(title='White wine POS')
# Out:
# [Text(0.5, 1.0, 'White wine POS')]

# %% [markdown]
# ### Concatenate both wines

# %%
# add column wine type
red_wine_heatmap['wine type']='red'
white_wine_heatmap['wine type']='white'
wine=pd.concat([red_wine_heatmap, white_wine_heatmap])
wine
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4              0.70         0.00             1.9
# 1         1            7.8              0.88         0.00             2.6
# 2         2            7.8              0.76         0.04             2.3
# 3         3           11.2              0.28         0.56             1.9
# 4         5            7.4              0.66         0.00             1.8
# ...     ...            ...               ...          ...             ...
# 3956   4893            6.2              0.21         0.29             1.6
# 3957   4894            6.6              0.32         0.36             8.0
# 3958   4895            6.5              0.24         0.19             1.2
# 3959   4896            5.5              0.29         0.30             1.1
# 3960   4897            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
numberic_wine=wine.iloc[:, 0:12]
numberic_wine
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4              0.70         0.00             1.9
# 1         1            7.8              0.88         0.00             2.6
# 2         2            7.8              0.76         0.04             2.3
# 3         3           11.2              0.28         0.56             1.9
# 4         5            7.4              0.66         0.00             1.8
# ...     ...            ...               ...          ...             ...
# 3956   4893            6.2              0.21         0.29             1.6
# 3957   4894            6.6              0.32         0.36             8.0
# 3958   4895            6.5              0.24         0.19             1.2
# 3959   4896            5.5              0.29         0.30             1.1
# 3960   4897            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
corr=numberic_wine.corr()

# %%
matrix2=np.triu(corr)
plt.figure(figsize=(10,10))
diverging_palette=sns.diverging_palette(500, 300, s=120, as_cmap=True)
sns.heatmap(data=corr, mask=matrix2, square=True, cmap=diverging_palette, vmin=-1, vmax=1, annot=True, linewidths=0.5).set(title='WINE Corr')
# Out:
# [Text(0.5, 1.0, 'WINE Corr')]

# %% [markdown]
# ## HUE PLOTS

# %%
wine.head(1)
# Out:
#    index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0      0            7.4               0.7          0.0             1.9
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality wine type
# 0       0.56      9.4        5       red

# %%
color_red_white = ['Red', 'Yellow'] 
sns.countplot(data = wine , x = 'wine type', palette=color_red_white).set(title='Wine count')
# Out:
# [Text(0.5, 1.0, 'Wine count')]

# %%
color_red_white = ['Red', 'Yellow', 'Blues'] 
sns.countplot(data = wine , x = 'wine type', palette=color_red_white).set(title='Wine count')
sns.despine(left = True, bottom = True)

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
wine['quality label'] = wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
wine['quality label'] = pd.Categorical(wine['quality label'],
categories=['low', 'medium', 'high'])

# %%
# Regression plots 
sns.lmplot(x = 'pH' , y = 'alcohol', data = wine, hue = 'wine type',palette=color_red_white, scatter_kws = {'s' : 100})
# Out:
# c:\Users\gabb_\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x = 'alcohol' , y = 'residual sugar', data = wine,palette='rocket', hue = 'quality label', col = 'wine type',aspect = 0.8)
# Out:
# c:\Users\gabb_\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\gabb_\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
smallpos_wine=wine[['wine type','quality label', 'alcohol','citric acid','pH']]

# %%
sns.pairplot(smallpos_wine, hue = 'quality label', palette = 'coolwarm' )
# Out:
# c:\Users\gabb_\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig , ax = plt.subplots (figsize = (7,7))
gabi=['#dd1c77', '#fff7bc']
sns.barplot(x='quality label',y='residual sugar',data=wine, palette=gabi, hue='wine type', errorbar=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
plt.xticks(fontsize=10, color='white')
plt.yticks(fontsize=10, color='white')
ax.set_xlabel('Quality label', fontdict={'size': 12, 'color': 'white'})
ax.set_ylabel('Residual Sugar', fontdict={'size': 12, 'color': 'white'})
# sns.despine()

plt.title('Does Residual Sugar affect the quality of wine?', color='white')
plt.setp(ax.get_legend().get_texts(), fontsize='15', color='white') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='15', color='white') # for legend title
#legend_properties = {'weight':'bold'}
#plt.legend(property=legend_properties)
ax.get_legend().set_frame_on(False)
ax.get_legend().set_title("Wine types")

# %%
gabi=['#fa9fb5', '#fff7bc']
sns.barplot(x='quality label',y='residual sugar',data=wine, palette=gabi, hue='wine type', ci=None)
sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
# wine.set_xlabel("Quality Label", fontsize=8, color='white')
#slippers_plot.set_ylabel("", fontsize=18)
#sns.set_style(rc={"grid.color": "black", "grid.linestyle": ":"})
#sns.set_style("whitegrid", {'grid.color': 'red'})
# plt.figure(figsize=(12,8))
# slippers_plot = sns.barplot(data=slipper_colour,x='colour', y='total_units', palette='bright')
# slippers_plot
# slippers_plot.set_title("Top Slipper Colors", fontsize=20, pad=30, fontdict={"weight": "bold"})
# slippers_plot.set_xlabel("Total Units", fontsize=16)
# slippers_plot.set_ylabel("", fontsize=18)
plt.xticks(fontsize=6)
plt.yticks(fontsize=6)
sns.despine
# plt.grid(visible=None)
# Out:
# C:\Users\gabb_\AppData\Local\Temp\ipykernel_22380\2487475978.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='quality label',y='residual sugar',data=wine, palette=gabi, hue='wine type', ci=None)
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
sns.set_style ('white')
my_colors=['Red','Yellow']

title = "Wine Qiality-Sulphates'"
g=sns.jointplot(x='quality', y='sulphates', data=wine, hue='wine type', kind='kde', palette= my_colors, marginal_ticks=True, ratio=2, marginal_kws={'fill':True})
plt.suptitle(title, y = 1.05)
# Out:
# Text(0.5, 1.05, "Wine Qiality-Sulphates'")

# %%
# sns.set_style ('white')
# color='red', space=0.5, marginal_ticks=True
# title = "Red Wine Qiality-Sulphates'"
# g = sns.JointGrid(data=red_wine_heatmap, x='quality', y='sulphates')
# g.plot_joint(sns.scatterplot, color='red')
# g.plot_marginals(sns.histplot, color='red')
# plt.suptitle(title, y = 1.05)
# sns.despine(left=False, bottom=False, top=False, right=False)
# g.ax_marg_x.set_xlabels()
# g.ax_marg_x.set_ylabels()

sns.set_theme(rc={'axes.facecolor':'black', 'figure.facecolor':'black', 'grid.color': 'black' })
g = sns.JointGrid(marginal_ticks=True, space=1)
title = 'Red Wine Qiality-Sulphates'
plt.suptitle(title, color='white', y = 1.05)
x, y =wine.quality, wine.sulphates
sns.scatterplot(x=x, y=y, ax=g.ax_joint, color='red', s=100, alpha=0.4)
sns.histplot(x=x, ax=g.ax_marg_x, color='red', bins=20)
g.ax_marg_y.set_xlim(0, 500)
g.ax_marg_x.set_ylim(0, 500)
sns.histplot(y=y, ax=g.ax_marg_y, element='step', color='red', bins=17)
sns.despine(left=False, bottom=False, top=False, right=False)
g.ax_marg_y.tick_params(labelleft=True)
g.ax_marg_x.tick_params(labelbottom=True)
g.ax_joint.set_xlabel('Quality', color='white', fontweight='bold')
g.ax_joint.set_ylabel('Sulphates', color='white', fontweight='bold')
g.ax_marg_y.set_xlabel('')
g.ax_marg_x.set_ylabel('')
g.ax_joint.set_xticklabels(g.ax_joint.get_xticks(), color='white')
g.ax_joint.set_yticklabels(g.ax_joint.get_yticks(), color='white')
g.ax_marg_x.set_xticklabels(g.ax_marg_x.get_xticks(), color='white')
g.ax_marg_x.set_yticklabels(g.ax_marg_x.get_yticks(), color='white')
g.ax_marg_y.set_xticklabels(g.ax_marg_y.get_xticks(), color='white')
g.ax_marg_y.set_yticklabels(g.ax_marg_y.get_yticks(), color='white')
# Out:
# C:\Users\gabb_\AppData\Local\Temp\ipykernel_22380\2627785778.py:29: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.ax_joint.set_xticklabels(g.ax_joint.get_xticks(), color='white')
# C:\Users\gabb_\AppData\Local\Temp\ipykernel_22380\2627785778.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.ax_joint.set_yticklabels(g.ax_joint.get_yticks(), color='white')
# C:\Users\gabb_\AppData\Local\Temp\ipykernel_22380\2627785778.py:31: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.ax_marg_x.set_xticklabels(g.ax_marg_x.get_xticks(), color='white')
# C:\Users\gabb_\AppData\Local\Temp\ipykernel_22380\2627785778.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.ax_marg_x.set_yticklabels(g.ax_marg_x.get_yticks(), color='white')
# ...

# %%
# For example, take the feature named residual sugar and plot the distributions across data pertaining to red and white wine samples.

fig, axs= plt.subplots(nrows = 1, ncols= 2, figsize = (10,5))
fig.suptitle('Residual Sugar Content in Wine', fontsize= 16, fontweight='bold', color='black')
sns.histplot(bins=16, x = "residual sugar" , stat='count', data = red_wine_heatmap, color='#dd1c77', ax=axs[0])
sns.histplot(bins=16, x = "residual sugar" ,stat='count', data = white_wine_heatmap, fill=False, color='white',  ax=axs[1])
axs[0].set_xlabel('Residula sugar', fontdict={'size': 12, 'weight': 'bold', 'color': '#dd1c77'})
axs[0].set_ylabel('Frequency', fontdict={'size': 12, 'weight': 'bold', 'color': '#dd1c77'})
axs[1].set_xlabel('Residula sugar', fontdict={'size': 12, 'weight': 'bold', 'color': 'black'})
axs[1].set_ylabel('Frequency', fontdict={'size': 12, 'weight': 'bold', 'color': 'black'})
axs[0].set_ylim(0, 2500)
axs[1].set_ylim(0, 2500)
axs[1].set_title('White Wine', fontdict={'size': 15, 'weight': 'bold', 'color': 'white'})
axs[0].set_title('Red Wine', fontdict={'size': 15, 'weight': 'bold', 'color': '#dd1c77'})
# axs[0].set_facecolor("#636363")
# axs[1].set_facecolor("#636363")
# Out:
# Text(0.5, 1.0, 'Red Wine')
