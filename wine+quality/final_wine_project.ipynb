# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv', sep=';')
white_wine = pd.read_csv('winequality-white.csv', sep=';')

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
white_wine.shape
# Out:
# (4898, 12)

# %% [markdown]
# ## Isna()

# %%
red_wine.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
white_wine.isna()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
# ...

# %% [markdown]
# ## Isnull()

# %%
red_wine.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
white_wine.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 4893          False             False        False           False      False
# 4894          False             False        False           False      False
# 4895          False             False        False           False      False
# 4896          False             False        False           False      False
# 4897          False             False        False           False      False
#
# ...

# %% [markdown]
# ## Describe()

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ## Add column with low, medium, high

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %% [markdown]
# ## Check the new columns in both datasets

# %%
red_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label
# 0      9.4        5           low

# %%
white_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol  quality quality_label
# 0      8.8        6        medium

# %% [markdown]
# ## Add a new column with wine type

# %%
# we are creating a new column called "wine_type"
red_wine['wine_type'] = 'red'

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
red_wine['wine_type'] = pd.Categorical(red_wine['wine_type'], categories=['red'])

# %%
# we are creating a new column called "wine_type"
white_wine['wine_type'] = 'white'

# here we are transforming these labels into categrical data type (specific to pandas) instead of simple string
white_wine['wine_type'] = pd.Categorical(white_wine['wine_type'], categories=['white'])

# %% [markdown]
# ## Check both datasets

# %%
red_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4               0.7          0.0             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality quality_label wine_type
# 0      9.4        5           low       red

# %%
white_wine.head(1)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                 45.0                 170.0    1.001  3.0       0.45
#
#    alcohol  quality quality_label wine_type
# 0      8.8        6        medium     white

# %% [markdown]
# ## Standardizing name columns

# %%
white_wine = white_wine.rename(columns=lambda x: x.replace(' ', '_'))
white_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine = red_wine.rename(columns=lambda x: x.replace(' ', '_'))
red_wine
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ## Concat Describe for finding trends

# %% [markdown]
# Fixed acidity: acids are major wine properties and contribute greatly to the wine’s taste. Usually, the total acidity is divided into two groups: the volatile acids and the nonvolatile or fixed acids. Among the fixed acids that you can find in wines are the following: tartaric, malic, citric, and succinic. This variable is expressed in g(tartaricacid)/dm3 in the data sets.
#
# Volatile acidity: the volatile acidity is basically the process of wine turning into vinegar. In the U.S, the legal limits of Volatile Acidity are 1.2 g/L for red table wine and 1.1 g/L for white table wine. In these data sets, the volatile acidity is expressed in g(aceticacid)/dm3.
#
# Citric acid is one of the fixed acids that you’ll find in wines. It’s expressed in g/dm3 in the two data sets. Residual sugar typically refers to the sugar remaining after fermentation stops, or is stopped. It’s expressed in g/dm3 in the red and white data.
#
# Chlorides can be a significant contributor to saltiness in wine. Here, you’ll see that it’s expressed in g(sodiumchloride)/dm3.
#
# Free sulfur dioxide: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. This variable is expressed in mg/dm3 in the data.
#
# Total sulfur dioxide is the sum of the bound and the free sulfur dioxide (SO2). Here, it’s expressed in mg/dm3. There are legal limits for sulfur levels in wines: in the EU, red wines can only have 160mg/L, while white and rose wines can have about 210mg/L. Sweet wines are allowed to have 400mg/L. For the US, the legal limits are set at 350mg/L, and for Australia, this is 250mg/L.
#
# Density is generally used as a measure of the conversion of sugar to alcohol. Here, it’s expressed in g/cm3.
#
# pH or the potential of hydrogen is a numeric scale to specify the acidity or basicity the wine. As you might know, solutions with a pH less than 7 are acidic, while solutions with a pH greater than 7 are basic. With a pH of 7, pure water is neutral. Most wines have a pH between 2.9 and 3.9 and are therefore acidic.
#
# Sulfates are to wine as gluten is to food. You might already know sulfites from the headaches that they can cause. They are a regular part of wine making around the world and are considered necessary. In this case, they are expressed in g(potassiumsulphate)/dm3.
#
# Alcohol: wine is an alcoholic beverage, and as you know, the percentage of alcohol can vary from wine to wine. It shouldn’t be surprised that this variable is included in the data sets, where it’s expressed in % vol.
#
# Quality: wine experts graded the wine quality between 0 (very bad) and 10 (very excellent). The eventual number is the mean of at least three evaluations made by those same wine experts. Some analysts might combine these levels to Low, Medium & High-Quality wines.

# %%
#sulfates and volatile acidity are already clear

# %% [markdown]
# You can observe that the mean value of sulfates and volatile acidity seem to be higher in red wine as compared to white wine.
#
# Come up with few more observation and write them down in the form of #comment in your VSCode. This will help you undestand which features is worth investigating further, keeping in mind that we are trying first to understand the difference between red and white wines, and then their respective relations with the quality label.

# %%
pd.concat([red_wine.describe(), white_wine.describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                               \
#         fixed_acidity volatile_acidity  citric_acid residual_sugar
# count     1599.000000      1599.000000  1599.000000    1599.000000
# mean         8.319637         0.527821     0.270976       2.538806
# std          1.741096         0.179060     0.194801       1.409928
# min          4.600000         0.120000     0.000000       0.900000
# 25%          7.100000         0.390000     0.090000       1.900000
# 50%          7.900000         0.520000     0.260000       2.200000
# 75%          9.200000         0.640000     0.420000       2.600000
# max         15.900000         1.580000     1.000000      15.500000
#
#                                                                           \
#          chlorides free_sulfur_dioxide total_sulfur_dioxide      density
# count  1599.000000         1599.000000          1599.000000  1599.000000
# mean      0.087467           15.874922            46.467792     0.996747
# ...

# %%
pd.concat([red_wine[['residual_sugar', 'total_sulfur_dioxide','sulphates', 'alcohol','volatile_acidity','quality']].describe(), white_wine[['residual_sugar', 'total_sulfur_dioxide','sulphates', 'alcohol','volatile_acidity','quality']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                                                 \
#        residual_sugar total_sulfur_dioxide    sulphates      alcohol
# count     1599.000000          1599.000000  1599.000000  1599.000000
# mean         2.538806            46.467792     0.658149    10.422983
# std          1.409928            32.895324     0.169507     1.065668
# min          0.900000             6.000000     0.330000     8.400000
# 25%          1.900000            22.000000     0.550000     9.500000
# 50%          2.200000            38.000000     0.620000    10.200000
# 75%          2.600000            62.000000     0.730000    11.100000
# max         15.500000           289.000000     2.000000    14.900000
#
#                                     White Wines Stats                       \
#       volatile_acidity      quality    residual_sugar total_sulfur_dioxide
# count      1599.000000  1599.000000       4898.000000          4898.000000
# ...

# %% [markdown]
# ### Fixed aciditiy is HIGHER in red wine

# %%
# AVG of fixed acidiy for red wine is higher than for the white wine/ std big difference

# Fixed acidity: acids are major wine properties and contribute greatly to the wine’s taste. Usually, the total acidity is divided into 
# two groups: the volatile acids and the nonvolatile or fixed acids. Among the fixed acids that you can find in wines are the following:
# tartaric, malic, citric, and succinic. This variable is expressed in g(tartaricacid)/dm3 in the data sets.

pd.concat([red_wine[['fixed_acidity','volatile_acidity']].describe(), white_wine[['fixed_acidity','volatile_acidity' ]].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats                  White Wines Stats
#         fixed_acidity volatile_acidity     fixed_acidity volatile_acidity
# count     1599.000000      1599.000000       4898.000000      4898.000000
# mean         8.319637         0.527821          6.854788         0.278241
# std          1.741096         0.179060          0.843868         0.100795
# min          4.600000         0.120000          3.800000         0.080000
# 25%          7.100000         0.390000          6.300000         0.210000
# 50%          7.900000         0.520000          6.800000         0.260000
# 75%          9.200000         0.640000          7.300000         0.320000
# max         15.900000         1.580000         14.200000         1.100000

# %%
sns.boxplot(x = "quality_label" , y = "fixed_acidity", data = red_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='fixed_acidity'>

# %% [markdown]
# ### Free sulfur dioxide is LOWER in red wine

# %%
# AVG free sulfur dioxide for white wine is two times higher than the red whine/std also higher for white wine
# Free sulfur dioxide: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, 
# while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. 
# This variable is expressed in mg/dm3 in the data.

pd.concat([red_wine[['free_sulfur_dioxide']].describe(), white_wine[['free_sulfur_dioxide']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#           Red Wines Stats   White Wines Stats
#       free_sulfur_dioxide free_sulfur_dioxide
# count         1599.000000         4898.000000
# mean            15.874922           35.308085
# std             10.460157           17.007137
# min              1.000000            2.000000
# 25%              7.000000           23.000000
# 50%             14.000000           34.000000
# 75%             21.000000           46.000000
# max             72.000000          289.000000

# %%
sns.boxplot(x = "quality_label" , y = "free_sulfur_dioxide", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='free_sulfur_dioxide'>

# %% [markdown]
# ### Chloride is HIGHER in red wine

# %%
# avg cloride is higher for the red wine compared to the white wine also std
# Chlorides can be a significant contributor to saltiness in wine. Here, you’ll see that it’s expressed in g(sodiumchloride)/dm3

pd.concat([red_wine[['chlorides']].describe(), white_wine[['chlorides']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats White Wines Stats
#             chlorides         chlorides
# count     1599.000000       4898.000000
# mean         0.087467          0.045772
# std          0.047065          0.021848
# min          0.012000          0.009000
# 25%          0.070000          0.036000
# 50%          0.079000          0.043000
# 75%          0.090000          0.050000
# max          0.611000          0.346000

# %%
sns.boxplot(x = "quality_label" , y = "chlorides", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='chlorides'>

# %% [markdown]
# ### Residual sugar is 3 times LOWER  in red wine

# %%
# avg residual sugar us 3 times higher for white wine also std
pd.concat([red_wine[['residual_sugar']].describe(), white_wine[['residual_sugar']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats White Wines Stats
#        residual_sugar    residual_sugar
# count     1599.000000       4898.000000
# mean         2.538806          6.391415
# std          1.409928          5.072058
# min          0.900000          0.600000
# 25%          1.900000          1.700000
# 50%          2.200000          5.200000
# 75%          2.600000          9.900000
# max         15.500000         65.800000

# %%
sns.boxplot(x = "quality_label" , y = "residual_sugar", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='residual_sugar'>

# %% [markdown]
# ### Pie Chart REd and White

# %%
white_wine_count=white_wine['quality'].count()
red_wine_count=red_wine['quality'].count()

# %%
sizes=[red_wine_count, white_wine_count]
labels='Red Wine','White Wine'
explode=(0,0.5)
mycolors=['pink','yellow']

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode,autopct='%1.1f%%', pctdistance=0.5, startangle=45,colors=mycolors)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# ax1.set_title('White wine + Red wine',loc='left')

ax1.legend(labels,
          title="Wine types",
          loc="center left",
          bbox_to_anchor=(0, 0.5, 0.3, 1))
plt.show()

# %%
pd.concat([red_wine[['quality','alcohol']].describe(), white_wine[['quality','alcohol']].describe()], axis=1, keys=["Red Wines Stats", "White Wines Stats"])
# Out:
#       Red Wines Stats              White Wines Stats
#               quality      alcohol           quality      alcohol
# count     1599.000000  1599.000000       4898.000000  4898.000000
# mean         5.636023    10.422983          5.877909    10.514267
# std          0.807569     1.065668          0.885639     1.230621
# min          3.000000     8.400000          3.000000     8.000000
# 25%          5.000000     9.500000          5.000000     9.500000
# 50%          6.000000    10.200000          6.000000    10.400000
# 75%          6.000000    11.100000          6.000000    11.400000
# max          8.000000    14.900000          9.000000    14.200000

# %%
my_palette=sns.cubehelix_palette(start=.5, rot=-.75, as_cmap=True)

# %%
fig, axs= plt.subplots(nrows = 1, ncols= 2, sharey = True, figsize = (10,8))
sns.boxplot(x = "quality_label" , y = "alcohol", data = red_wine, palette='rocket' , ax=axs[1])
sns.boxplot(x = "quality_label" , y = "alcohol", data = white_wine, ax=axs[0])
axs[0].set_title('White Wine')
axs[1].set_title('Red Wine')
axs[1].set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
sns.boxplot(x = "quality_label" , y = "alcohol", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='alcohol'>

# %%
sns.boxplot(x = "quality_label" , y = "residual_sugar", data = red_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='residual_sugar'>

# %%
sns.boxplot(x = "quality_label" , y = "density", data = red_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='density'>

# %%
sns.boxplot(x = "quality_label" , y = "density", data = white_wine )
# Out:
# <Axes: xlabel='quality_label', ylabel='density'>

# %%
sns.scatterplot(x = "residual_sugar" , y = "quality", data = red_wine , hue= "quality_label")
# Out:
# <Axes: xlabel='residual_sugar', ylabel='quality'>
